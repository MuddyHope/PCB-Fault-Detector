# %%
from utils import get_model, predict, TEST_DIR
# Out:
# /opt/homebrew/anaconda3/envs/529/lib/python3.10/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
get_model()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Path stored in /Users/apple/Documents/CSUF/Spring 26/529/PCB-Fault-Detector/model.h5
# Model Loaded Successfully

# %%
# Test1
test_case_1_path = str(TEST_DIR)+"/bad/00041015_test.jpg"

predict(test_case_1_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Path stored in /Users/apple/Documents/CSUF/Spring 26/529/PCB-Fault-Detector/model.h5
# Model Loaded Successfully
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# [[9.9979073e-01 2.0926005e-04]]
# [[1. 0.]]
# 'Bad'

# %%
# Test2

test_case_2_path = str(TEST_DIR)+"/good/00041138_temp.jpg"

predict(test_case_2_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Path stored in /Users/apple/Documents/CSUF/Spring 26/529/PCB-Fault-Detector/model.h5
# Model Loaded Successfully
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# [[0.00296189 0.9970381 ]]
# [[0. 1.]]
# 'Good'

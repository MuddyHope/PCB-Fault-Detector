# %%
from utils import get_model, predict

# %%
get_model()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model Loaded Successfully

# %%
# Test1
test_case_1_path = "/Users/apple/Documents/CSUF/Spring 26/529/Circuit-Board-Fault-Detection-using-ML-main/Dataset/test/bad/00041015_test.jpg"

predict(test_case_1_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# [[0.95478714 0.04521289]]
# [[1. 0.]]
# 'Bad'

# %%
# Test2

test_case_2_path = "/Users/apple/Documents/CSUF/Spring 26/529/Circuit-Board-Fault-Detection-using-ML-main/Dataset/test/good/00041138_temp.jpg"

predict(test_case_2_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[7.9422200e-04 9.9920577e-01]]
# [[0. 1.]]
# 'Good'
